# %%
pip install roboflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="9axcOwJ00juJKSOXwHGC")
project = rf.workspace().project("faulty-detection")
model = project.version(2).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# image path
image_path = 'dataset1/test_set/faulty/image_0_7880.jpeg'

# %%
from PIL import Image

# %%
image = Image.open(image_path)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
# infer on a local image
print(model.predict(image_path, confidence=70, overlap=50).json())
# Out:
# {'predictions': [{'x': 96.0, 'y': 144.0, 'width': 14.0, 'height': 14.0, 'confidence': 0.7529455423355103, 'class': 'faulty', 'image_path': 'dataset1/test_set/faulty/image_0_7880.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 58.5, 'y': 24.5, 'width': 13.0, 'height': 13.0, 'confidence': 0.7344713807106018, 'class': 'faulty', 'image_path': 'dataset1/test_set/faulty/image_0_7880.jpeg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 93.0, 'y': 167.5, 'width': 12.0, 'height': 15.0, 'confidence': 0.7195292711257935, 'class': 'faulty', 'image_path': 'dataset1/test_set/faulty/image_0_7880.jpeg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '224', 'height': '224'}}

# %%
# visualize your prediction
model.predict(image_path, confidence=70, overlap=50).save("prediction.jpg")

# %%
# infer on an image hosted elsewhere
# print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="9axcOwJ00juJKSOXwHGC")
project = rf.workspace().project("faulty-detection")
model = project.version(2).model

# infer on a local image
print(model.predict("your_image.jpg", confidence=40, overlap=30).json())

# visualize your prediction
model.predict("your_image.jpg", confidence=40, overlap=30).save("prediction.jpg")

# infer on an image hosted elsewhere
print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())
